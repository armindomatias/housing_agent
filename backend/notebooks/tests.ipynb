# %%
import time

# %%
def my_generator():
    print("Starting")
    yield 1
    print("After yield 1")
    yield time.sleep(10)
    print("After yield 2")
    yield 3

gen = my_generator()

# %%
value1 = next(gen)
# Out:
# Starting

# %%
value1
# Out:
# 1

# %%
next(gen)
# Out:
# After yield 1

# %%
next(gen)
# Out:
# After yield 2
# 3

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 next(gen)
#
# StopIteration:
